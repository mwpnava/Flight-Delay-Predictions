# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/df_flight_weather_1.csv')
# Out:
# C:\Users\tccox\AppData\Local\Temp\ipykernel_3624\4058589671.py:1: DtypeWarning: Columns (4,5,21,31,32,35,38,39,49,52,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../datasets/df_flight_weather_1.csv')

# %%
#print head
df.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0      1    1            4      AA            LAX                 PBI
# 1      1    1            4      US            SFO                 CLT
# 2      1    1            4      AA            LAX                 MIA
# 3      1    1            4      AS            SEA                 ANC
# 4      1    1            4      DL            SFO                 MSP
#
#   SCHEDULED_DEPARTURE DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  ...  \
# 0               00:10          00:02             -8.0      12.0  ...
# 1               00:20          00:18             -2.0      16.0  ...
# 2               00:20          00:15             -5.0      15.0  ...
# 3               00:25          00:24             -1.0      11.0  ...
# 4               00:25          00:20             -5.0      18.0  ...
#
#    pressure_dest  vis_dest  wc_dest  wdir_dest  wspd_dest  precip_hrly_dest  \
# ...

# %%
#print null sum
print(df.isnull().sum())
# Out:
# MONTH                           0
# DAY                             0
# DAY_OF_WEEK                     0
# AIRLINE                         0
# ORIGIN_AIRPORT                  0
# DESTINATION_AIRPORT             0
# SCHEDULED_DEPARTURE             0
# DEPARTURE_TIME                  0
# DEPARTURE_DELAY                 0
# TAXI_OUT                        0
# WHEELS_OFF                      0
# SCHEDULED_TIME                  0
# ELAPSED_TIME                    0
# AIR_TIME                        0
# DISTANCE                        0
# WHEELS_ON                       0
# TAXI_IN                         0
# SCHEDULED_ARRIVAL               0
# ARRIVAL_TIME                    0
# ARRIVAL_DELAY                   0
# day_of_year                     0
# day_ind                    491091
# temp                       495474
# wx_icon                    493517
# icon_extd                  493517
# dewPt                      499065
# heat_index                 499110
# ...

# %%
#print # of unique types for each column
val = {}
for col in df.columns:
    val[col] = len(df[col].unique())

for key, value in val.items():
    print(key, value)
# Out:
# MONTH 12
# DAY 31
# DAY_OF_WEEK 7
# AIRLINE 14
# ORIGIN_AIRPORT 929
# DESTINATION_AIRPORT 926
# SCHEDULED_DEPARTURE 1282
# DEPARTURE_TIME 1437
# DEPARTURE_DELAY 1175
# TAXI_OUT 182
# WHEELS_OFF 1439
# SCHEDULED_TIME 519
# ELAPSED_TIME 712
# AIR_TIME 675
# DISTANCE 1347
# WHEELS_ON 1438
# TAXI_IN 179
# SCHEDULED_ARRIVAL 1283
# ARRIVAL_TIME 1433
# ARRIVAL_DELAY 1195
# day_of_year 365
# day_ind 3
# temp 167
# wx_icon 34
# icon_extd 130
# dewPt 127
# heat_index 157
# rh 102
# pressure 903
# vis 27
# wc 188
# wdir 50
# wdir_cardinal 20
# wspd 64
# precip_hrly 224
# uv_desc 6
# feels_like 190
# uv_index 17
# wx_phrase_simple 17
# day_ind_dest 3
# temp_dest 148
# wx_icon_dest 34
# icon_extd_dest 125
# dewPt_dest 121
# heat_index_dest 143
# rh_dest 101
# pressure_dest 883
# vis_dest 26
# wc_dest 171
# wdir_dest 44
# wspd_dest 56
# precip_hrly_dest 170
# uv_desc_dest 6
# feels_like_dest 179
# uv_index_dest 16
# wx_phrase_simple_dest 17

# %%
#for each column that has nulls and is data type string or object to 'NA'
for col in df.columns:
    if df[col].isnull().sum() > 0 and df[col].dtype == 'object':
        df[col].fillna('NA', inplace=True)

# %%
#datatype
df.dtypes
# Out:
# MONTH                      int64
# DAY                        int64
# DAY_OF_WEEK                int64
# AIRLINE                   object
# ORIGIN_AIRPORT            object
# DESTINATION_AIRPORT       object
# SCHEDULED_DEPARTURE       object
# DEPARTURE_TIME            object
# DEPARTURE_DELAY          float64
# TAXI_OUT                 float64
# WHEELS_OFF               float64
# SCHEDULED_TIME           float64
# ELAPSED_TIME             float64
# AIR_TIME                 float64
# DISTANCE                   int64
# WHEELS_ON                float64
# TAXI_IN                  float64
# SCHEDULED_ARRIVAL         object
# ARRIVAL_TIME              object
# ARRIVAL_DELAY            float64
# day_of_year                int64
# day_ind                   object
# temp                     float64
# wx_icon                  float64
# icon_extd                float64
# dewPt                    float64
# heat_index               float64
# rh                       float64
# ...

# %%
#print null sum
print(df.isnull().sum())
# Out:
# MONTH                           0
# DAY                             0
# DAY_OF_WEEK                     0
# AIRLINE                         0
# ORIGIN_AIRPORT                  0
# DESTINATION_AIRPORT             0
# SCHEDULED_DEPARTURE             0
# DEPARTURE_TIME                  0
# DEPARTURE_DELAY                 0
# TAXI_OUT                        0
# WHEELS_OFF                      0
# SCHEDULED_TIME                  0
# ELAPSED_TIME                    0
# AIR_TIME                        0
# DISTANCE                        0
# WHEELS_ON                       0
# TAXI_IN                         0
# SCHEDULED_ARRIVAL               0
# ARRIVAL_TIME                    0
# ARRIVAL_DELAY                   0
# day_of_year                     0
# day_ind                         0
# temp                       500380
# wx_icon                    497452
# icon_extd                  497452
# dewPt                      505854
# heat_index                 505941
# ...

# %%
#print unique v

# %%
#length
print(len(df))
# Out:
# 15360464

# %%
print(df.columns)
# Out:
# Index(['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
#        'DEPARTURE_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME',
#        'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN',
#        'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'day_of_year',
#        'day_ind', 'temp', 'wx_icon', 'icon_extd', 'dewPt', 'heat_index', 'rh',
#        'pressure', 'vis', 'wc', 'wdir', 'wdir_cardinal', 'wspd', 'precip_hrly',
#        'uv_desc', 'feels_like', 'uv_index', 'wx_phrase_simple',
#        'day_of_year_orig', 'day_ind_dest', 'temp_dest', 'wx_icon_dest',
#        'icon_extd_dest', 'dewPt_dest', 'heat_index_dest', 'rh_dest',
#        'pressure_dest', 'vis_dest', 'wc_dest', 'wdir_dest', 'wspd_dest',
#        'precip_hrly_dest', 'uv_desc_dest', 'feels_like_dest', 'uv_index_dest',
#        'wx_phrase_simple_dest', 'day_of_year_dest'],
#       dtype='object')

# %%
#drop colimns day_of_year_dest, day_of_year_orig,
if 'day_of_year_dest' in df.columns:
    df.drop('day_of_year_dest', axis=1, inplace=True)
if 'day_of_year_orig' in df.columns:
    df.drop('day_of_year_orig', axis=1, inplace=True)
