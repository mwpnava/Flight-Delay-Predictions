# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/df_flight_weather_7.csv')
df.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT  \
# 0      1             2            5      DL            LAX
# 1      1             2            5      AA            LAS
# 2      1             2            5      US            PHX
# 3      1             2            5      DL            SLC
# 4      1             2            5      DL            SEA
#
#   DESTINATION_AIRPORT  DEPARTURE_DELAY_MIN  ELAPSED_TIME  AIR_TIME  \
# 0                 MSP                 24.0         205.0     185.0
# 1                 MIA                  3.0         269.0     248.0
# 2                 DTW                  2.0         204.0     181.0
# 3                 ATL                  1.0         202.0     178.0
# 4                 MSP                 -5.0         182.0     165.0
#
#    ARRIVAL_DELAY_MIN  ...  WDIR_CARDINAL_DEST WSPD_DEST  UV_DESC_DEST  \
# 0               15.0  ...                   W      13.0           Low
# ...

# %%
#print columns
df.columns
# df.head()
# Out:
# Index(['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'DEPARTURE_DELAY_MIN', 'ELAPSED_TIME',
#        'AIR_TIME', 'ARRIVAL_DELAY_MIN', 'DAY_OF_YEAR', 'DAY_IND', 'TEMP',
#        'WX_ICON', 'ICON_EXTD', 'DEWPT', 'HEAT_INDEX', 'RH', 'PRESSURE', 'VIS',
#        'WC', 'WDIR', 'WDIR_CARDINAL', 'WSPD', 'UV_DESC', 'FEELS_LIKE',
#        'UV_INDEX', 'CLDS', 'WX_PHRASE_SIMPLE', 'DAY_IND_DEST', 'TEMP_DEST',
#        'WX_ICON_DEST', 'ICON_EXTD_DEST', 'DEWPT_DEST', 'HEAT_INDEX_DEST',
#        'RH_DEST', 'PRESSURE_DEST', 'VIS_DEST', 'WC_DEST', 'WDIR_DEST',
#        'WDIR_CARDINAL_DEST', 'WSPD_DEST', 'UV_DESC_DEST', 'FEELS_LIKE_DEST',
#        'UV_INDEX_DEST', 'CLDS_DEST', 'WX_PHRASE_SIMPLE_DEST',
#        'SCHEDULED_DEPATURE_HR', 'SCHEDULED_ARRIVAL_HR',
#        'ARRIVAL_DELAY_MIN_CAT'],
#       dtype='object')

# %%
#remove columns
#ELAPSED_TIME, AIR_TIME
if 'ELAPSED_TIME' in df.columns:
    df.drop(['ELAPSED_TIME'], axis=1, inplace=True)
if 'AIR_TIME' in df.columns:
    df.drop(['AIR_TIME'], axis=1, inplace=True)

#DEPARTURE_DELAY
if 'DEPARTURE_DELAY' in df.columns:
    df.drop(['DEPARTURE_DELAY'], axis=1, inplace=True)

    #WX_ICON_DEST, WX_ICON
if 'WX_ICON_DEST' in df.columns:
    df.drop(['WX_ICON_DEST'], axis=1, inplace=True)

if 'WX_ICON' in df.columns:
    df.drop(['WX_ICON'], axis=1, inplace=True)

# %%
#save csv
df.to_csv('../datasets/df_flight_weather_8.csv', index=False)
