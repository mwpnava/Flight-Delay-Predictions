# %%
import os
import pandas as pd

# %%
import pandas as pd

# Load the data
df = pd.read_csv('../datasets/weather_8.csv')

df['time_of_day'] = df['valid_time_gmt'].str[11:13].astype(int)
# df.head()


# Create a DataFrame with all possible combinations of filename, day_of_year, and time_of_day
filenames = df['filename'].unique()
days_of_year = range(1, 366)
times_of_day = range(1, 25)
index = pd.MultiIndex.from_product([filenames, days_of_year, times_of_day], names=['filename', 'day_of_year', 'time_of_day'])
template = pd.DataFrame(index=index).reset_index()

# Merge the template with the original data to fill in missing values
merged = pd.merge(template, df, how='left', on=['filename', 'day_of_year', 'time_of_day'])

# Forward-fill missing values
merged = merged.groupby('filename').apply(lambda x: x.ffill())

# Save the result to a new file
merged.to_csv('../datasets/weather_9.csv', index=False)

# %%
#read df head
import datetime


file_path = '../datasets/weather_9.csv'
df = pd.read_csv(file_path)
df.head()

#add new column time_of_day; 0-23, round down to floor hour
if 'time_of_day' not in df.columns:
    df['time_of_day'] = df['valid_time_gmt'].str[11:13].astype(int)
df.head()

#fill in missing valid_time_gmt with assuming year is 2015, use columns 'day_of_year' (0-364) and 'time_of_day' (0-23)
#to calculate valid_time_gmt

year = 2015


#convert day_of_year and time_of_day to float
df['day_of_year'] = df['day_of_year'].astype(float)
df['time_of_day'] = df['time_of_day'].astype(float)

#fill in missing values; lambda function to calculate valid_time_gmt
df['valid_time_gmt'] = df['valid_time_gmt'].fillna(df.apply(lambda row: datetime.datetime(year, 1, 1) + datetime.timedelta(days=row['day_of_year'], hours=row['time_of_day']), axis=1))

df.head()
# Out:
#   filename  day_of_year  time_of_day       valid_time_gmt day_ind  temp  \
# 0  ABE.csv          1.0          1.0  2016-01-01 01:51:00       N  41.0
# 1  ABE.csv          1.0          2.0  2016-01-01 02:51:00       N  40.0
# 2  ABE.csv          1.0          3.0  2016-01-01 03:51:00       N  39.0
# 3  ABE.csv          1.0          4.0  2016-01-01 04:51:00       N  39.0
# 4  ABE.csv          1.0          5.0  2016-01-01 04:51:00       N  39.0
#
#    wx_icon  icon_extd  dewPt  heat_index  ...    wc   wdir  wdir_cardinal  \
# 0     26.0     2600.0   27.0        41.0  ...  34.0  280.0              W
# 1     26.0     2600.0   27.0        40.0  ...  33.0  280.0              W
# 2     26.0     2600.0   27.0        39.0  ...  34.0  280.0              W
# 3     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 4     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
#
#    wspd precip_hrly uv_desc  feels_like  uv_index clds  wx_phrase_simple
# 0  12.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 1  12.0         0.0     Low        33.0       0.0  OVC            Cloudy
# 2   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 3   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 4   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
#
# [5 rows x 23 columns]

# %%
#for each unique filename; log the filename that doesn't have 365 days of data
#and also log the filename that doesnt have 24 hours of data for each day

#group by filename
grouped = df.groupby('filename')

#log file
log_file = open('weather_prep_log.txt', 'w')

full_success = True

#loop through each group
for name, group in grouped:

    #check if each group has 365 days of data
    if len(group['day_of_year'].unique()) != 365:
        log_file.write(f'{name} days: {len(group["day_of_year"].unique())}/{365} \n')
        full_success = False
        continue

    #check if each group has 24 hours of data for each day
    for day in group['day_of_year'].unique():
        if len(group.loc[group['day_of_year'] == day]['time_of_day'].unique()) != 24:
            log_file.write(f'{name} day {day} hours: {len(group.loc[group["day_of_year"] == day]["time_of_day"].unique())}/{24} \n')
            full_success = False
            continue

print('full_success: ' + str(full_success))
#close log file
log_file.close()
# Out:
# full_success: True

# %%
#list columns
df.columns
# Out:
# Index(['valid_time_gmt', 'day_ind', 'temp', 'wx_icon', 'icon_extd', 'dewPt',
#        'heat_index', 'rh', 'pressure', 'vis', 'wc', 'wdir', 'wdir_cardinal',
#        'wspd', 'precip_hrly', 'uv_desc', 'feels_like', 'uv_index', 'clds',
#        'filename', 'wx_phrase_simple', 'day_of_year', 'time_of_day'],
#       dtype='object')

# %%
#count nulls
df.isnull().sum()
# Out:
# filename                0
# day_of_year             0
# time_of_day             0
# valid_time_gmt          0
# day_ind                66
# temp                   66
# wx_icon                67
# icon_extd              67
# dewPt                  66
# heat_index             66
# rh                     66
# pressure               98
# vis                  8826
# wc                     66
# wdir                   66
# wdir_cardinal          66
# wspd                   66
# precip_hrly         53885
# uv_desc                66
# feels_like             66
# uv_index               66
# clds                   66
# wx_phrase_simple       66
# dtype: int64

# %%
#override valid_time_gmt column with datetime object using year = 2015, day_of_year, and time_of_day
df['valid_time_gmt'] = df.apply(lambda row: datetime.datetime(year, 1, 1) + datetime.timedelta(days=row['day_of_year'], hours=row['time_of_day']), axis=1)

# %%
df.head(48)
# Out:
#    filename  day_of_year  time_of_day      valid_time_gmt day_ind  temp  \
# 0   ABE.csv          1.0          1.0 2015-01-02 01:00:00       N  41.0
# 1   ABE.csv          1.0          2.0 2015-01-02 02:00:00       N  40.0
# 2   ABE.csv          1.0          3.0 2015-01-02 03:00:00       N  39.0
# 3   ABE.csv          1.0          4.0 2015-01-02 04:00:00       N  39.0
# 4   ABE.csv          1.0          5.0 2015-01-02 05:00:00       N  39.0
# 5   ABE.csv          1.0          6.0 2015-01-02 06:00:00       N  39.0
# 6   ABE.csv          1.0          7.0 2015-01-02 07:00:00       N  39.0
# 7   ABE.csv          1.0          8.0 2015-01-02 08:00:00       N  39.0
# 8   ABE.csv          1.0          9.0 2015-01-02 09:00:00       N  39.0
# 9   ABE.csv          1.0         10.0 2015-01-02 10:00:00       N  39.0
# 10  ABE.csv          1.0         11.0 2015-01-02 11:00:00       N  39.0
# 11  ABE.csv          1.0         12.0 2015-01-02 12:00:00       N  39.0
# 12  ABE.csv          1.0         13.0 2015-01-02 13:00:00       N  39.0
# 13  ABE.csv          1.0         14.0 2015-01-02 14:00:00       N  39.0
# 14  ABE.csv          1.0         15.0 2015-01-02 15:00:00       N  39.0
# 15  ABE.csv          1.0         16.0 2015-01-02 16:00:00       N  39.0
# 16  ABE.csv          1.0         17.0 2015-01-02 17:00:00       N  39.0
# 17  ABE.csv          1.0         18.0 2015-01-02 18:00:00       N  39.0
# 18  ABE.csv          1.0         19.0 2015-01-02 19:00:00       N  39.0
# 19  ABE.csv          1.0         20.0 2015-01-02 20:00:00       N  39.0
# 20  ABE.csv          1.0         21.0 2015-01-02 21:00:00       N  39.0
# 21  ABE.csv          1.0         22.0 2015-01-02 22:00:00       N  39.0
# 22  ABE.csv          1.0         23.0 2015-01-02 23:00:00       N  39.0
# 23  ABE.csv          1.0         24.0 2015-01-03 00:00:00       N  39.0
# 24  ABE.csv          2.0          1.0 2015-01-03 01:00:00       N  39.0
# 25  ABE.csv          2.0          2.0 2015-01-03 02:00:00       N  39.0
# 26  ABE.csv          2.0          3.0 2015-01-03 03:00:00       N  39.0
# 27  ABE.csv          2.0          4.0 2015-01-03 04:00:00       N  29.0
# 28  ABE.csv          2.0          5.0 2015-01-03 05:00:00       N  30.0
# 29  ABE.csv          2.0          6.0 2015-01-03 06:00:00       N  29.0
# 30  ABE.csv          2.0          7.0 2015-01-03 07:00:00       N  31.0
# 31  ABE.csv          2.0          8.0 2015-01-03 08:00:00       N  27.0
# 32  ABE.csv          2.0          9.0 2015-01-03 09:00:00       N  29.0
# 33  ABE.csv          2.0         10.0 2015-01-03 10:00:00       N  30.0
# 34  ABE.csv          2.0         11.0 2015-01-03 11:00:00       N  29.0
# 35  ABE.csv          2.0         12.0 2015-01-03 12:00:00       D  30.0
# 36  ABE.csv          2.0         13.0 2015-01-03 13:00:00       D  33.0
# 37  ABE.csv          2.0         14.0 2015-01-03 14:00:00       D  37.0
# 38  ABE.csv          2.0         15.0 2015-01-03 15:00:00       D  39.0
# 39  ABE.csv          2.0         16.0 2015-01-03 16:00:00       D  39.0
# 40  ABE.csv          2.0         17.0 2015-01-03 17:00:00       D  41.0
# 41  ABE.csv          2.0         18.0 2015-01-03 18:00:00       D  41.0
# 42  ABE.csv          2.0         19.0 2015-01-03 19:00:00       D  41.0
# 43  ABE.csv          2.0         20.0 2015-01-03 20:00:00       D  40.0
# 44  ABE.csv          2.0         21.0 2015-01-03 21:00:00       N  36.0
# 45  ABE.csv          2.0         22.0 2015-01-03 22:00:00       N  36.0
# 46  ABE.csv          2.0         23.0 2015-01-03 23:00:00       N  34.0
# 47  ABE.csv          2.0         24.0 2015-01-04 00:00:00       N  34.0
#
#     wx_icon  icon_extd  dewPt  heat_index  ...    wc   wdir  wdir_cardinal  \
# 0      26.0     2600.0   27.0        41.0  ...  34.0  280.0              W
# 1      26.0     2600.0   27.0        40.0  ...  33.0  280.0              W
# 2      26.0     2600.0   27.0        39.0  ...  34.0  280.0              W
# 3      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 4      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 5      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 6      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 7      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 8      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 9      26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 10     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 11     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 12     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 13     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 14     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 15     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 16     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 17     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 18     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 19     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 20     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 21     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 22     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 23     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 24     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 25     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 26     26.0     2600.0   27.0        39.0  ...  34.0  290.0            WNW
# 27     29.0     2900.0   15.0        29.0  ...  22.0  200.0            SSW
# 28     33.0     3300.0   16.0        30.0  ...  23.0  210.0            SSW
# 29     29.0     2900.0   17.0        29.0  ...  21.0  220.0             SW
# 30     29.0     2900.0   16.0        31.0  ...  23.0  240.0            WSW
# 31     29.0     2900.0   15.0        27.0  ...  20.0  220.0             SW
# 32     33.0     3300.0   16.0        29.0  ...  20.0  220.0             SW
# 33     27.0     2700.0   17.0        30.0  ...  22.0  230.0             SW
# 34     27.0     2700.0   16.0        29.0  ...  20.0  230.0             SW
# 35     26.0     2600.0   17.0        30.0  ...  22.0  230.0             SW
# 36     26.0     2600.0   17.0        33.0  ...  25.0  220.0             SW
# 37     28.0     2800.0   18.0        37.0  ...  30.0  250.0            WSW
# 38     28.0     2800.0   18.0        39.0  ...  31.0  250.0            WSW
# 39     26.0     2600.0   18.0        39.0  ...  32.0  290.0            WNW
# 40     28.0     2800.0   17.0        41.0  ...  33.0  270.0              W
# 41     30.0     3000.0   18.0        41.0  ...  34.0  270.0              W
# 42     30.0     3000.0   18.0        41.0  ...  36.0  290.0            WNW
# 43     30.0     3000.0   17.0        40.0  ...  34.0  300.0            WNW
# 44     33.0     3300.0   17.0        36.0  ...  36.0      ?           CALM
# 45     29.0     2900.0   18.0        36.0  ...  36.0      ?           CALM
# 46     29.0     2900.0   18.0        34.0  ...  34.0  250.0            WSW
# 47     29.0     2900.0   18.0        34.0  ...  34.0  250.0            WSW
#
#     wspd precip_hrly uv_desc  feels_like  uv_index clds  wx_phrase_simple
# 0   12.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 1   12.0         0.0     Low        33.0       0.0  OVC            Cloudy
# 2    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 3    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 4    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 5    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 6    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 7    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 8    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 9    7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 10   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 11   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 12   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 13   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 14   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 15   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 16   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 17   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 18   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 19   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 20   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 21   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 22   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 23   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 24   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 25   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 26   7.0         0.0     Low        34.0       0.0  OVC            Cloudy
# 27   7.0         0.0     Low        22.0       0.0  CLR     Partly Cloudy
# 28   7.0         0.0     Low        23.0       0.0  CLR              Fair
# 29   8.0         0.0     Low        21.0       0.0  CLR     Partly Cloudy
# 30   9.0         0.0     Low        23.0       0.0  CLR     Partly Cloudy
# 31   6.0         0.0     Low        20.0       0.0  CLR     Partly Cloudy
# 32   9.0         0.0     Low        20.0       0.0  CLR              Fair
# 33   8.0         0.0     Low        22.0       0.0  BKN     Mostly Cloudy
# 34   9.0         0.0     Low        20.0       0.0  SCT     Mostly Cloudy
# 35   8.0         0.0     Low        22.0       1.0  OVC            Cloudy
# 36  10.0         0.0     Low        25.0       1.0  OVC            Cloudy
# 37  10.0         0.0     Low        30.0       1.0  BKN     Mostly Cloudy
# 38  15.0         0.0     Low        31.0       1.0  BKN     Mostly Cloudy
# 39  10.0         0.0     Low        32.0       1.0  OVC            Cloudy
# 40  15.0         0.0     Low        33.0       2.0  FEW     Mostly Cloudy
# 41  12.0         0.0     Low        34.0       1.0  SCT     Partly Cloudy
# 42   8.0         0.0     Low        36.0       1.0  FEW     Partly Cloudy
# 43   8.0         0.0     Low        34.0       1.0  CLR     Partly Cloudy
# 44   0.0         0.0     Low        36.0       0.0  CLR              Fair
# 45   0.0         0.0     Low        36.0       0.0  CLR     Partly Cloudy
# 46   3.0         0.0     Low        34.0       0.0  CLR     Partly Cloudy
# 47   3.0         0.0     Low        34.0       0.0  CLR     Partly Cloudy
#
# [48 rows x 23 columns]

# %%
#fill all na with its previous value
df = df.fillna(method='ffill')

#check if there are any nulls
df.isnull().sum()
# Out:
# filename            0
# day_of_year         0
# time_of_day         0
# valid_time_gmt      0
# day_ind             0
# temp                0
# wx_icon             0
# icon_extd           0
# dewPt               0
# heat_index          0
# rh                  0
# pressure            0
# vis                 0
# wc                  0
# wdir                0
# wdir_cardinal       0
# wspd                0
# precip_hrly         0
# uv_desc             0
# feels_like          0
# uv_index            0
# clds                0
# wx_phrase_simple    0
# dtype: int64

# %%
#remove duplicates if they exist for 'filename', 'day_of_year', 'time_of_day'
df = df.drop_duplicates(subset=['filename', 'day_of_year', 'time_of_day'], keep='first')

# %%
#save to csv
df.to_csv('../datasets/weather_10.csv', index=False)
